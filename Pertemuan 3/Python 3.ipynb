# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.7.4.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.1.31)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.4.1)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from kaggle) (5.29.4)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.11/dist-packages (from kaggle) (75.1.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.3.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from kaggle) (0.5.1)

# %%
# !kaggle datasets list -s "goal leagues"
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 4, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.11/dist-packages/kaggle/__init__.py", line 6, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.11/dist-packages/kaggle/api/kaggle_api_extended.py", line 433, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.config/kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/

# %%
# !kaggle datasets download shreyanshkhandelwal/goal-dataset-top-5-european-leagues
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/kaggle/cli.py", line 68, in main
#     out = args.func(**command_args)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/kaggle/api/kaggle_api_extended.py", line 1734, in dataset_download_cli
#     with self.build_kaggle_client() as kaggle:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/kaggle/api/kaggle_api_extended.py", line 688, in build_kaggle_client
#     username=self.config_values['username'],
#              ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'username'

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)

# %%
import pandas as pd
import numpy as np

# %%
path = "epl-goalScorer(20-21).csv"
df = pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-c761f2d00d3f> in <cell line: 0>()
#       1 path = "epl-goalScorer(20-21).csv"
# ----> 2 df = pd.read_csv(path)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'epl-goalScorer(20-21).csv'

# %%
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-9447ae629b41> in <cell line: 0>()
# ----> 1 df.head(3)
#
# NameError: name 'df' is not defined

# %%
df.tail(7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-762b955aa2d9> in <cell line: 0>()
# ----> 1 df.tail(7)
#
# NameError: name 'df' is not defined

# %%
print(df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-42a6bcf1a5e9> in <cell line: 0>()
# ----> 1 print(df.dtypes)
#
# NameError: name 'df' is not defined

# %%
df_noid = df.iloc[:,2:]
df_noid
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-f19edb169bdf> in <cell line: 0>()
# ----> 1 df_noid = df.iloc[:,2:]
#       2 df_noid
#
# NameError: name 'df' is not defined

# %%
df1 = df_noid.sort_values(by="player_name",ascending=True)
df1.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-ea25c785e92e> in <cell line: 0>()
# ----> 1 df1 = df_noid.sort_values(by="player_name",ascending=True)
#       2 df1.head(10)
#
# NameError: name 'df_noid' is not defined

# %%
df1 = df_noid.sort_values(by=["assists", "team_title"],
                          ascending=[False,True])
df1.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-71c148e6091e> in <cell line: 0>()
# ----> 1 df1 = df_noid.sort_values(by=["assists", "team_title"],
#       2                           ascending=[False,True])
#       3 df1.head(10)
#
# NameError: name 'df_noid' is not defined

# %%
df_noid.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-43eff396f6b1> in <cell line: 0>()
# ----> 1 df_noid.describe()
#
# NameError: name 'df_noid' is not defined

# %%
df_noid[['goals', 'games', 'assists', 'shots']].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-edad4ddb988f> in <cell line: 0>()
# ----> 1 df_noid[['goals', 'games', 'assists', 'shots']].mean()
#
# NameError: name 'df_noid' is not defined

# %%
df_noid[['goals', 'games', 'assists', 'shots']].median()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-d517caa39b15> in <cell line: 0>()
# ----> 1 df_noid[['goals', 'games', 'assists', 'shots']].median()
#
# NameError: name 'df_noid' is not defined

# %%
df_noid[['team_title']].mode()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-666902324632> in <cell line: 0>()
# ----> 1 df_noid[['team_title']].mode()
#
# NameError: name 'df_noid' is not defined

# %%
df_noid[['goals']].quantile(q=0.75)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-5843754f630e> in <cell line: 0>()
# ----> 1 df_noid[['goals']].quantile(q=0.75)
#
# NameError: name 'df_noid' is not defined

# %%
print(df_noid.dtypes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-93aa2cdc9ad5> in <cell line: 0>()
# ----> 1 print(df_noid.dtypes)
#
# NameError: name 'df_noid' is not defined

# %%
df_noid = df_noid.select_dtypes(include=["number"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-dd38b186fa5e> in <cell line: 0>()
# ----> 1 df_noid = df_noid.select_dtypes(include=["number"])
#
# NameError: name 'df_noid' is not defined

# %%
df_noid.quantile(0.75)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-55c6eeb866ba> in <cell line: 0>()
# ----> 1 df_noid.quantile(0.75)
#
# NameError: name 'df_noid' is not defined

# %%
df_noid[['goals']].var(), df_noid[['goals']].std()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-cb84a6f6b039> in <cell line: 0>()
# ----> 1 df_noid[['goals']].var(), df_noid[['goals']].std()
#
# NameError: name 'df_noid' is not defined

# %%
mean = df_noid[['goals']].mean()
stdev = df_noid[['goals']].std()
iso = (df_noid[['goals']] < mean - 3*stdev) \
    | (df_noid[['goals']] > mean + 3*stdev)

df1 = df_noid[['goals']].assign(is_outlier=iso)
df1.loc[df1['is_outlier']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-0691e8260e44> in <cell line: 0>()
# ----> 1 mean = df_noid[['goals']].mean()
#       2 stdev = df_noid[['goals']].std()
#       3 iso = (df_noid[['goals']] < mean - 3*stdev) \
#       4     | (df_noid[['goals']] > mean + 3*stdev)
#       5
#
# NameError: name 'df_noid' is not defined

# %%
q1 = df_noid['goals'].quantile(q=0.25)
q3 = df_noid['goals'].quantile(q=0.75)
iqr = q3 - q1
iso = (df_noid['goals'] < q1 - 1.5*iqr) | (df_noid['goals'] > q3 + 1.5*iqr)
iseo = (df_noid['goals'] < q1 - 3*iqr) | (df_noid['goals'] > q3 + 3*iqr)
df1 = df_noid[['goals']].assign(is_outlier = iso, is_extreme_outlier = iseo)
df1.loc[df1['is_outlier'] | df1['is_extreme_outlier']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-f78526144166> in <cell line: 0>()
# ----> 1 q1 = df_noid['goals'].quantile(q=0.25)
#       2 q3 = df_noid['goals'].quantile(q=0.75)
#       3 iqr = q3 - q1
#       4 iso = (df_noid['goals'] < q1 - 1.5*iqr) | (df_noid['goals'] > q3 + 1.5*iqr)
#       5 iseo = (df_noid['goals'] < q1 - 3*iqr) | (df_noid['goals'] > q3 + 3*iqr)
#
# NameError: name 'df_noid' is not defined

# %%
df['team_title'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-88858724b7c6> in <cell line: 0>()
# ----> 1 df['team_title'].value_counts()
#
# NameError: name 'df' is not defined

# %%
df_noid.groupby('time')[['goals']]\
.mean().sort_values(by='goals', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-e95baea9e7e9> in <cell line: 0>()
# ----> 1 df_noid.groupby('time')[['goals']]\
#       2 .mean().sort_values(by='goals', ascending=False)
#
# NameError: name 'df_noid' is not defined

# %%
df.loc[:, 'games':].select_dtypes(include=['number']).corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-0210a2aa40a8> in <cell line: 0>()
# ----> 1 df.loc[:, 'games':].select_dtypes(include=['number']).corr()
#
# NameError: name 'df' is not defined
