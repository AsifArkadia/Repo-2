# %% [markdown]
# Praktek TF-IDF
# =============================
#
# ***Universitas Dian Nuswantoro***

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('clean_dataset_stem.csv',sep=';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-354f805ac70b> in <cell line: 0>()
# ----> 1 dataset = pd.read_csv('clean_dataset_stem.csv',sep=';')
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'clean_dataset_stem.csv'

# %%
dataset_feature = dataset['ProcessedText'].astype(str)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c960c7731e25> in <cell line: 0>()
# ----> 1 dataset_feature = dataset['ProcessedText'].astype(str)
#
# NameError: name 'dataset' is not defined

# %%
dataset_feature
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ec328d14f495> in <cell line: 0>()
# ----> 1 dataset_feature
#
# NameError: name 'dataset_feature' is not defined

# %%
dataset.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a62c974a6759> in <cell line: 0>()
# ----> 1 dataset.shape
#
# NameError: name 'dataset' is not defined

# %%
dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3075b36c09c8> in <cell line: 0>()
# ----> 1 dataset
#
# NameError: name 'dataset' is not defined

# %%
dataset_label = dataset['Sentimen']
dataset_label
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-5277a7c712a8> in <cell line: 0>()
# ----> 1 dataset_label = dataset['Sentimen']
#       2 dataset_label
#
# NameError: name 'dataset' is not defined

# %% [markdown]
# # cek distribusi label

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Visualizing the target variable
plt.figure(figsize=(12,8))
sns.distplot(dataset_label, label=f'target, skew: {dataset_label.skew():.2f}')
plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-6b19bd2067b7> in <cell line: 0>()
#       1 # Visualizing the target variable
#       2 plt.figure(figsize=(12,8))
# ----> 3 sns.distplot(dataset_label, label=f'target, skew: {dataset_label.skew():.2f}')
#       4 plt.legend(loc='best')
#       5 plt.show()
#
# NameError: name 'dataset_label' is not defined

# %%
dataset_label.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-67d13ef1ff47> in <cell line: 0>()
# ----> 1 dataset_label.value_counts()
#
# NameError: name 'dataset_label' is not defined

# %% [markdown]
# # TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

# %%
X = vectorizer.fit_transform(dataset_feature)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-96c219a2365e> in <cell line: 0>()
# ----> 1 X = vectorizer.fit_transform(dataset_feature)
#
# NameError: name 'dataset_feature' is not defined

# %%
print(X.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-94cb9ce28558> in <cell line: 0>()
# ----> 1 print(X.shape)
#
# NameError: name 'X' is not defined

# %%
features = vectorizer.get_feature_names_out()
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-15-ea24350da5cc> in <cell line: 0>()
# ----> 1 features = vectorizer.get_feature_names_out()
#
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_extraction/text.py in get_feature_names_out(self, input_features)
#    1470             Transformed feature names.
#    1471         """
# -> 1472         self._check_vocabulary()
#    1473         return np.asarray(
#    1474             [t for t, i in sorted(self.vocabulary_.items(), key=itemgetter(1))],
#
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_extraction/text.py in _check_vocabulary(self)
#     499             self._validate_vocabulary()
#     500             if not self.fixed_vocabulary_:
# --> 501                 raise NotFittedError("Vocabulary not fitted or provided")
#     502
#     503         if len(self.vocabulary_) == 0:
#
# NotFittedError: Vocabulary not fitted or provided

# %%
features
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-224628ecf868> in <cell line: 0>()
# ----> 1 features
#
# NameError: name 'features' is not defined

# %%
idfValues = vectorizer.idf_
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-17-43c870f43186> in <cell line: 0>()
# ----> 1 idfValues = vectorizer.idf_
#
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_extraction/text.py in idf_(self)
#    2010         """
#    2011         if not hasattr(self, "_tfidf"):
# -> 2012             raise NotFittedError(
#    2013                 f"{self.__class__.__name__} is not fitted yet. Call 'fit' with "
#    2014                 "appropriate arguments before using this attribute."
#
# NotFittedError: TfidfVectorizer is not fitted yet. Call 'fit' with appropriate arguments before using this attribute.

# %%
d = dict(zip(features, 9 - idfValues))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-022728bbd5b9> in <cell line: 0>()
# ----> 1 d = dict(zip(features, 9 - idfValues))
#
# NameError: name 'features' is not defined

# %%
sortedDict = sorted(d.items(), key = lambda d: d[1], reverse = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-90c515cee11a> in <cell line: 0>()
# ----> 1 sortedDict = sorted(d.items(), key = lambda d: d[1], reverse = True)
#
# NameError: name 'd' is not defined

# %%
for i in range(3867):
    print(sortedDict[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-a3d45d96e9e9> in <cell line: 0>()
#       1 for i in range(3867):
# ----> 2     print(sortedDict[i])
#
# NameError: name 'sortedDict' is not defined

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plot

# %%
def PlotWordCloud(frequency):
    worcloudPlot = WordCloud(background_color="white", width=1500, height=1000)
    worcloudPlot.generate_from_frequencies(frequencies=frequency)
    plot.figure(figsize=(15,10))
    plot.imshow(worcloudPlot, interpolation="bilinear")
    plot.axis("off")
    plot.show()

# %%
PlotWordCloud(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-98d9353bfc07> in <cell line: 0>()
# ----> 1 PlotWordCloud(d)
#
# NameError: name 'd' is not defined
